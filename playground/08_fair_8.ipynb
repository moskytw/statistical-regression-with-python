# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import IPython as ip

# %%
mpl.style.use('ggplot')
mpl.rc('figure', figsize=(8.0, 5.5))
mpl.rc('font', family='Noto Sans CJK TC')
ip.display.set_matplotlib_formats('svg')

# %%
df_fair = sm.datasets.fair.load_pandas().data

# %%
df = df_fair
smf.ols('affairs ~ rate_marriage', df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                affairs   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     208.4
# Date:                Wed, 01 May 2019   Prob (F-statistic):           1.66e-46
# Time:                        13:07:02   Log-Likelihood:                -13959.
# No. Observations:                6366   AIC:                         2.792e+04
# Df Residuals:                    6364   BIC:                         2.794e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         2.3825      0.119     19.969      0.000       2.149       2.616
# rate_marriage    -0.4081      0.028    -14.436      0.000      -0.464      -0.353
# ==============================================================================
# Omnibus:                     9443.528   Durbin-Watson:                   1.606
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5215639.758
# Skew:                           8.930   Prob(JB):                         0.00
# Kurtosis:                     142.083   Cond. No.                         19.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df = df_fair
smf.ols('np.log(affairs+1) ~ rate_marriage', df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     np.log(affairs + 1)   R-squared:                       0.076
# Model:                             OLS   Adj. R-squared:                  0.076
# Method:                  Least Squares   F-statistic:                     527.1
# Date:                 Wed, 01 May 2019   Prob (F-statistic):          3.98e-112
# Time:                         13:06:53   Log-Likelihood:                -5038.3
# No. Observations:                 6366   AIC:                         1.008e+04
# Df Residuals:                     6364   BIC:                         1.009e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.9469      0.029     32.225      0.000       0.889       1.004
# rate_marriage    -0.1598      0.007    -22.958      0.000      -0.173      -0.146
# ==============================================================================
# Omnibus:                     2845.649   Durbin-Watson:                   1.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13276.573
# Skew:                           2.189   Prob(JB):                         0.00
# Kurtosis:                       8.557   Cond. No.                         19.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df = df_fair
smf.ols('np.sqrt(affairs) ~ rate_marriage', df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       np.sqrt(affairs)   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     564.7
# Date:                Wed, 01 May 2019   Prob (F-statistic):          1.16e-119
# Time:                        13:07:14   Log-Likelihood:                -6819.0
# No. Observations:                6366   AIC:                         1.364e+04
# Df Residuals:                    6364   BIC:                         1.366e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         1.3022      0.039     33.504      0.000       1.226       1.378
# rate_marriage    -0.2188      0.009    -23.763      0.000      -0.237      -0.201
# ==============================================================================
# Omnibus:                     3310.905   Durbin-Watson:                   0.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26251.886
# Skew:                           2.380   Prob(JB):                         0.00
# Kurtosis:                      11.735   Cond. No.                         19.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
